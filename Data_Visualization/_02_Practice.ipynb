# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go

# %%
airline_data =  pd.read_csv('./airline_data.csv', 
                            encoding = "ISO-8859-1",
                            dtype={'Div1Airport': str, 'Div1TailNum': str, 
                                   'Div2Airport': str, 'Div2TailNum': str})

# %%
data = airline_data.sample(n=500, random_state=42)
data.shape
# Out:
# (500, 110)

# %%
fig = go.Figure()

# %%
fig.add_trace(go.Scatter(x=data['Distance'], y=data['DepTime'], mode='markers', marker=dict(color='red')))

# %%
fig.update_layout(title ='Distance vs Departure time', xaxis_title='Distance', yaxis_title="DeptTime")
fig.show()

# %%
airline_data
# Out:
#        Unnamed: 0  Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 0         1295781  1998        2      4           2          4  1998-04-02
# 1         1125375  2013        2      5          13          1  2013-05-13
# 2          118824  1993        3      9          25          6  1993-09-25
# 3          634825  1994        4     11          12          6  1994-11-12
# 4         1888125  2017        3      8          17          4  2017-08-17
# ...           ...   ...      ...    ...         ...        ...         ...
# 26995      821542  2017        1      1          24          2  2017-01-24
# 26996     1910565  2013        2      6          27          4  2013-06-27
# 26997        9055  2016        3      8          26          5  2016-08-26
# 26998       84136  2009        3      8           8          6  2009-08-08
# 26999      113029  1993        3      7          17          6  1993-07-17
#
# ...

# %%
airline_data['DestStateName']
# Out:
# 0        Washington
# 1          Virginia
# 2          Illinois
# 3           Arizona
# 4          Colorado
#             ...
# 26995     Minnesota
# 26996         Texas
# 26997      New York
# 26998      Colorado
# 26999         Texas
# Name: DestStateName, Length: 27000, dtype: object

# %%
airline_data[['Reporting_Airline', 'Flights']]
# Out:
#       Reporting_Airline  Flights
# 0                    AS      1.0
# 1                    EV      1.0
# 2                    UA      1.0
# 3                    HP      1.0
# 4                    UA      1.0
# ...                 ...      ...
# 26995                DL      1.0
# 26996                B6      1.0
# 26997                AA      1.0
# 26998                YV      1.0
# 26999                DL      1.0
#
# [27000 rows x 2 columns]

# %%
airline_data.groupby(by = ['Month', 'Reporting_Airline']).head()
# Out:
#        Unnamed: 0  Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 0         1295781  1998        2      4           2          4  1998-04-02
# 1         1125375  2013        2      5          13          1  2013-05-13
# 2          118824  1993        3      9          25          6  1993-09-25
# 3          634825  1994        4     11          12          6  1994-11-12
# 4         1888125  2017        3      8          17          4  2017-08-17
# ...           ...   ...      ...    ...         ...        ...         ...
# 26477     1203509  1990        4     12           3          1  1990-12-03
# 26647       56916  1988        3      8          29          1  1988-08-29
# 26665      452334  2004        2      6          28          1  2004-06-28
# 26733      506581  2018        3      8           5          7  2018-08-05
# 26753     1649282  2006        2      6          28          3  2006-06-28
#
# ...

# %%
import pandas as pd
df = pd.read_csv('automobileEDA.csv')

# %%
df.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# ...

# %%
df_filter = df.groupby(by=['drive-wheels', 'body-style'], as_index=True)
df_filter[['drive-wheels', 'body-style']].head()
# Out:
#     drive-wheels   body-style
# 0            rwd  convertible
# 1            rwd  convertible
# 2            rwd    hatchback
# 3            fwd        sedan
# 4            4wd        sedan
# 5            fwd        sedan
# 6            fwd        sedan
# 7            fwd        wagon
# 8            fwd        sedan
# 9            rwd        sedan
# 10           rwd        sedan
# 11           rwd        sedan
# 12           rwd        sedan
# 13           rwd        sedan
# 17           fwd    hatchback
# 18           fwd    hatchback
# 19           fwd        sedan
# 20           fwd    hatchback
# 21           fwd    hatchback
# 22           fwd    hatchback
# 27           fwd        wagon
# 35           fwd        wagon
# 43           rwd    hatchback
# 52           rwd    hatchback
# 53           rwd    hatchback
# 54           rwd    hatchback
# 65           rwd        wagon
# 66           rwd      hardtop
# 69           rwd  convertible
# 71           rwd      hardtop
# ...
