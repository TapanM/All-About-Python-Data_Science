# %%
import requests
import pandas as pd

# %%
url = "https://dog.ceo/api/breeds/list/all"
data = requests.get(url)
data.co

# %%
df = pd.DataFrame(data)
df
# Out:
#                                                     0
# 0   b'{"message":{"affenpinscher":[],"african":[],...
# 1   b'agle":[],"bluetick":[],"borzoi":[],"bouvier"...
# 2   b',"english","french"],"bullterrier":["staffor...
# 3   b':[],"collie":["border"],"coonhound":[],"corg...
# 4   b'eerhound":["scottish"],"dhole":[],"dingo":[]...
# 5   b'phund"],"frise":["bichon"],"germanshepherd":...
# 6   b',"blood","english","ibizan","plott","walker"...
# 7   b'abrador":[],"leonberg":[],"lhasa":[],"malamu...
# 8   b'rless":[],"mix":[],"mountain":["bernese","sw...
# 9   b'nese":[],"pembroke":[],"pinscher":["miniatur...
# 10  b'dium","miniature","standard","toy"],"pug":[]...
# 11  b'd","golden"],"ridgeback":["rhodesian"],"rott...
# 12  b'],"segugio":["italian"],"setter":["english",...
# 13  b'":[],"spaniel":["blenheim","brittany","cocke...
# 14  b'"stbernard":[],"terrier":["american","austra...
# 15  b'orfolk","norwich","patterdale","russell","sc...
# ...
